# %% [markdown]
# ## Create a Variable

# %% [markdown]
# variable_name = "variable_value"

# %%
salary = 100000
bonus_rate = 0.10
print(salary)
# Out:
# 100000

# %%
total_salary = salary + salary * bonus_rate

# %%
maleeran_salary = 5000

# %%
my_company = "Google"
my_company
# Out:
# 'Google'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 my_company.size
#
# AttributeError: 'str' object has no attribute 'size'
